# %% [markdown]
# # 運用pandas將讀取的資料表格顯示

# %% [markdown]
# ### 1.讀取excel

# %%
import pandas as pd

df = pd.read_excel("gdplev.xlsx")
df.head()
# Out:
#   Unnamed: 0 Current-Dollar and "Real" Gross Domestic Product  \
# 0        NaN                                              NaN
# 1     Annual                                              NaN
# 2        NaN                                              NaN
# 3        NaN                                              NaN
# 4        NaN               GDP in billions of current dollars
#
#                                 Unnamed: 2  Unnamed: 3  \
# 0                                      NaN         NaN
# 1                                      NaN         NaN
# 2                                      NaN         NaN
# 3                                      NaN         NaN
# 4  GDP in billions of chained 2009 dollars         NaN
#
#                              Unnamed: 4                          Unnamed: 5  \
# 0                                   NaN                                 NaN
# 1                             Quarterly                                 NaN
# ...

# %% [markdown]
# ### 2.讀取csv

# %%
df_2 = pd.read_csv("City_Zhvi_AllHomes.csv")
df_2.head()
# Out:
#    RegionID    RegionName State                           Metro    CountyName  \
# 0      6181      New York    NY                        New York         Kings
# 1     12447   Los Angeles    CA  Los Angeles-Long Beach-Anaheim   Los Angeles
# 2     17426       Chicago    IL                         Chicago          Cook
# 3     13271  Philadelphia    PA                    Philadelphia  Philadelphia
# 4     40326       Phoenix    AZ                         Phoenix      Maricopa
#
#    SizeRank   1996-04   1996-05   1996-06   1996-07  ...  2017-05  2017-06  \
# 0         1  189300.0  188900.0  188400.0  187500.0  ...   668100   678400
# 1         2  155000.0  154600.0  154400.0  154200.0  ...   631500   634600
# 2         3  109700.0  109400.0  109300.0  109300.0  ...   220200   220300
# 3         4   50000.0   49900.0   49600.0   49400.0  ...   136900   137700
# 4         5   87200.0   87700.0   88200.0   88400.0  ...   212700   215300
#
# ...
